# %% [markdown]
# #Exercises 13
# #**Pandas**

# %% [markdown]
# **Exercuses 1**
#
# *  **Load the dataset (cancer.csv)!**

# %%
import pandas as pd

# %%
df=pd.read_csv('/content/cancer.csv')

# %% [markdown]
# **Exercuses 2**
#
# *  **Print an overview of the dataset.**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 75 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   State                                         51 non-null     object
#  1   Total.Rate                                    51 non-null     float64
#  2   Total.Number                                  51 non-null     float64
#  3   Total.Population                              51 non-null     float64
#  4   Rates.Age.< 18                                51 non-null     float64
#  5   Rates.Age.18-45                               51 non-null     float64
#  6   Rates.Age.45-64                               51 non-null     float64
#  7   Rates.Age.> 64                                51 non-null     float64
#  8   Rates.Age and Sex.< 18.Female                 51 non-null     float64
# ...

# %% [markdown]
# **Exercuses 3**
#
# **Print 13 last samples of the dataset.**

# %%
df.tail(13)
# Out:
#              State  Total.Rate  Total.Number  Total.Population  \
# 38    Pennsylvania       227.7      202230.0        88825682.0
# 39    Rhode Island       211.2       15570.0         7371636.0
# 40  South Carolina       202.6       65561.0        32366134.0
# 41    South Dakota       196.2       11212.0         5714307.0
# 42       Tennessee       213.1       94678.0        44430836.0
# 43           Texas       145.8      257000.0       176270421.0
# 44            Utah        98.5       19022.0        19321462.0
# 45         Vermont       211.6        9261.0         4377262.0
# 46        Virginia       177.1       99278.0        56054333.0
# 47      Washington       175.9       82864.0        47114240.0
# 48   West Virginia       254.6       32950.0        12940212.0
# 49       Wisconsin       197.5       78578.0        39788899.0
# 50         Wyoming       167.9        6603.0         3931624.0
#
#     Rates.Age.< 18  Rates.Age.18-45  Rates.Age.45-64  Rates.Age.> 64  \
# ...

# %% [markdown]
# **Exercuses 4**
#
# **Print states with total rate of less than 200**

# %%
df.columns
# Out:
# Index(['State', 'Total.Rate', 'Total.Number', 'Total.Population',
#        'Rates.Age.< 18', 'Rates.Age.18-45', 'Rates.Age.45-64',
#        'Rates.Age.> 64', 'Rates.Age and Sex.< 18.Female',
#        'Rates.Age and Sex.< 18.Male', 'Rates.Age and Sex.18 - 45.Female',
#        'Rates.Age and Sex.18 - 45.Male', 'Rates.Age and Sex.45 - 64.Female',
#        'Rates.Age and Sex.45 - 64.Male', 'Rates.Age and Sex.> 64.Female',
#        'Rates.Age and Sex.> 64.Male', 'Rates.Race.White',
#        'Rates.Race.White non-Hispanic', 'Rates.Race.Black', 'Rates.Race.Asian',
#        'Rates.Race.Indigenous', 'Rates.Race and Sex.Female.White',
#        'Rates.Race and Sex.Female.White non-Hispanic',
#        'Rates.Race and Sex.Female.Black',
#        'Rates.Race and Sex.Female.Black non-Hispanic',
#        'Rates.Race and Sex.Female.Asian',
#        'Rates.Race and Sex.Female.Indigenous', 'Rates.Race and Sex.Male.White',
#        'Rates.Race and Sex.Male.White non-Hispanic',
# ...

# %%
df[df['Total.Rate']<200]['State'] 
# np.array(df[df['Total.Rate']<200]['State'] )
# Out:
# 1                   Alaska
# 2                  Arizona
# 4               California
# 5                 Colorado
# 6              Connecticut
# 8     District of Columbia
# 10                 Georgia
# 11                  Hawaii
# 12                   Idaho
# 13                Illinois
# 16                  Kansas
# 20                Maryland
# 21           Massachusetts
# 23               Minnesota
# 26                 Montana
# 27                Nebraska
# 28                  Nevada
# 29           New Hampshire
# 30              New Jersey
# 31              New Mexico
# 32                New York
# 33          North Carolina
# 34            North Dakota
# 37                  Oregon
# 41            South Dakota
# 43                   Texas
# 44                    Utah
# 46                Virginia
# 47              Washington
# 49               Wisconsin
# 50                 Wyoming
# Name: State, dtype: object

# %% [markdown]
# **Exercues 5**
#
# **Print number of states with total rate of less than 200**

# %%
df[df['Total.Rate']<200]['State'].count()

#(df['Total.Rate']<200).sum()
# Out:
# 31

# %% [markdown]
# **Exercues 6**
#
# *   **Print rows between 53 and 112 , and columns between 14 to 82 (use iloc)**

# %%
df.iloc[35:112,15:28]

#df.iloc[35:,15:28]
# Out:
#     Rates.Age and Sex.> 64.Female  Rates.Age and Sex.> 64.Male  \
# 35                          895.1                       1288.3
# 36                          855.6                       1279.4
# 37                          866.0                       1169.2
# 38                          898.6                       1276.5
# 39                          884.4                       1291.3
# 40                          775.1                       1195.1
# 41                          860.7                       1195.0
# 42                          834.4                       1294.7
# 43                          750.2                       1104.0
# 44                          611.6                        884.9
# 45                          872.8                       1165.8
# 46                          819.2                       1170.7
# 47                          852.4                       1142.0
# 48                          889.6                       1299.9
# ...

# %%
print(df.columns[27])
print(df.columns[15])
df.loc[35:,'Rates.Age and Sex.> 64.Male':'Rates.Race and Sex.Male.White']
# Out:
# Rates.Race and Sex.Male.White
# Rates.Age and Sex.> 64.Male
#     Rates.Age and Sex.> 64.Male  Rates.Race.White  \
# 35                       1288.3             185.3
# 36                       1279.4             190.2
# 37                       1169.2             173.7
# 38                       1276.5             177.7
# 39                       1291.3             176.7
# 40                       1195.1             175.1
# 41                       1195.0             163.3
# 42                       1294.7             189.4
# 43                       1104.0             162.5
# 44                        884.9             128.9
# 45                       1165.8             175.0
# 46                       1170.7             168.9
# 47                       1142.0             171.3
# 48                       1299.9             198.6
# 49                       1233.6             169.9
# 50                       1064.5             161.5
#
# ...

# %% [markdown]
# **Exercues 7**
#
# **print unique values of the Rates.Age.< 18 column!**

# %%
df['Rates.Age.< 18'].nunique()
# Out:
# 13

# %% [markdown]
# **Exercues 8**
#
# *   **print mean of the Rates.Age.< 18**

# %%
df['Rates.Age.< 18'].mean()
# Out:
# 2.119607843137255

# %% [markdown]
# **Exercues 9**
#
# **Find max of Total.Population and subtract all values of Total.Population column from the maximum value using lambda function**

# %%
max_vaul=df['Total.Population'].max()

# %%
df['Total.Population'].map(lambda x : max_vaul-x )
# Out:
# 0     227748491.0
# 1     256169516.0
# 2     216290098.0
# 3     240753248.0
# 4             0.0
# 5     225867962.0
# 6     236159807.0
# 7     254840433.0
# 8     256890337.0
# 9     128858625.0
# 10    193245044.0
# 11    251609613.0
# 12    250181401.0
# 13    171438735.0
# 14    215763006.0
# 15    239813614.0
# 16    241206913.0
# 17    230787639.0
# 18    229497310.0
# 19    251834514.0
# 20    220651717.0
# 21    215243424.0
# 22    191747123.0
# 23    223951967.0
# 24    240378824.0
# 25    219297306.0
# 26    254202673.0
# 27    248350172.0
# 28    242223389.0
# 29    251912307.0
# 30    199614141.0
# 31    246785934.0
# 32    125419172.0
# 33    194466627.0
# 34    256380793.0
# 35    180394453.0
# 36    234906552.0
# 37    234303580.0
# 38    172310014.0
# 39    253764060.0
# 40    228769562.0
# 41    255421389.0
# 42    216704860.0
# 43     84865275.0
# 44    241814234.0
# 45    256758434.0
# 46    205081363.0
# 47    214021456.0
# 48    248195484.0
# 49    221346797.0
# ...
